# %%
import pandas as pd

# %%
path = r'C:\Users\Thabang Ndhlovu\Projects\HELLO_CREDIT\resources\Ratings\cleaned_credit_ratings.xlsx'

# %%
df = pd.read_excel(path, index_col=0, parse_dates=True)

# %%
df.isna().sum()
# Out:
# Barloworld Limited                77
# Gold Fields Limited               72
# Bidvest Group Limited, The        72
# Sasol Limited                     68
# Growthpoint Properties Limited    69
# MTN Group Limited                 72
# Pepkor Holdings Limited           81
# Redefine Properties Limited       76
# Sappi Limited                     66
# Sibanye Stillwater Limited        83
# Telkom SA SOC Limited             68
# Zeda Limited                      84
# dtype: int64

# %%
for col in df:
    display(df[[col]].dropna())
# Out:
#               Barloworld Limited
# 2016-06-02                Stable
# 2017-06-13              Negative
# 2017-11-29  Ratings Under Review
# 2018-03-27                Stable
# 2019-11-07              Negative
# 2020-04-04              Negative
# 2020-11-26              Negative
# 2022-04-06                Stable
#              Gold Fields Limited
# 2010-09-17                Stable
# 2011-09-08              Positive
# 2012-10-01                Stable
# 2012-11-30  Ratings Under Review
# 2012-12-06              Negative
# 2014-05-13              Negative
# 2016-01-22  Ratings Under Review
# 2016-03-18                Stable
# 2016-09-16              Positive
# 2018-06-26                Stable
# 2020-04-04              Negative
# 2020-11-26              Negative
# 2022-04-06                Stable
#            Bidvest Group Limited, The
# 2012-06-13                     Stable
# 2014-11-07                     Stable
# 2016-05-11                   Negative
# ...

# %%
'ebitda_margin',
 'tot_debt_to_tot_eqy',
 'tot_debt_to_tot_asset',
 'tot_debt_to_ebitda',
 'ebitda_to_tot_int_exp',
 'interest_coverage_ratio',
 'tot_debt_to_tot_cap',
 'asset_turnover',
 'invent_to_sales'

fields = [
"return_on_asset(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"oper_margin(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"ebitda_margin(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"tot_debt_to_tot_eqy(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"tot_debt_to_tot_asset(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"tot_debt_to_ebitda(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"ebitda_to_tot_int_exp(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"interest_coverage_ratio(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"tot_debt_to_tot_cap(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"asset_turnover(fa_period_reference=range(2010,2018),fa_period_type='BA')",
"invent_to_sales(fa_period_reference=range(2010,2018),fa_period_type='BA')"]
 
    

 'ebitda_margin',
 'tot_debt_to_tot_eqy',
 'tot_debt_to_tot_asset',
 'tot_debt_to_ebitda',
 'ebitda_to_tot_int_exp',
 'interest_coverage_ratio',
 'tot_debt_to_tot_cap',
 'asset_turnover',
 'invent_to_sales']

universe = 'JALSH Index'

# %%
fields = [
"return_on_asset(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"oper_margin(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"ebitda_margin(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"tot_debt_to_tot_eqy(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"tot_debt_to_tot_asset(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"tot_debt_to_ebitda(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"ebitda_to_tot_int_exp(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"interest_coverage_ratio(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"tot_debt_to_tot_cap(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"asset_turnover(fa_period_reference=range(2000,2024),fa_period_type='BA')",
"invent_to_sales(fa_period_reference=range(2000,2024),fa_period_type='BA')"
]
