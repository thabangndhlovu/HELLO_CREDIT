# %% [markdown]
# # **Predictive Default Risk Assessor V.01**

# %% [markdown]
# # TODO
#
# * Base model
# * Comparison
# * Specialised
# * For small entities - Examples?
# * Backtest - All sectors
# * Understanding the model across all sectors/industries
# * Any markets - consumer goods, industries
# * UI last step after backtesting

# %%
import pandas as pd
import numpy as np

# %%
model_inputs = {
    "profitability": {
        "class_weight": 0.30,
        "weights": [1.0], 
        "metrics": {
            "oper_margin": {
                "lower_is_better": False,
                "thresholds": [
                    (40, float("inf")),
                    (35, 39),
                    (30, 34),
                    (25, 29),
                    (20, 24),
                    (15, 19),
                    (10, 14),
                    (5, 9),
                    (float("-inf"), 0)
                ],
            }
        },
    },
    "leverage_coverage": {
        "class_weight": 0.55,
        "weights": [0.4, 0.3, 0.3],
        "metrics": {
            "tot_debt_to_tot_eqy": {
                "lower_is_better": True,
                "thresholds": [
                     (float("-inf"), 2.0),
                     (2.0, 16.0),
                     (16.0, 24.0),
                     (24.0, 33.0),
                     (33.0, 43.0),
                     (43.0, 54.0),
                     (54.0, 68.0),
                     (68.0, 94.0),
                     (94.0, float("inf")),
                ],
            },
            "tot_debt_to_ebitda": {
                "lower_is_better": True,
                "thresholds": [
                    (float("-inf"), 0.09),
                    (0.09, 0.49),
                    (0.49, 0.9),
                    (0.9, 1.36),
                    (1.36, 1.68),
                    (1.68, 2.26),
                    (2.26, 3.27),
                    (3.27, 4.4),
                    (4.4, float("inf")),
                ],
            },
            "ebitda_to_tot_int_exp": {
                "lower_is_better": False,
                "thresholds": [
                    (25, float("inf")),
                    (20, 25),
                    (15, 20),
                    (10, 15),
                    (5, 10),
                    (3, 5),
                    (1, 3),
                    (0, 1),
                    (float("-inf"), 0),
                ],
            },
        },
    },
    "efficiency": {
        "class_weight": 0.15,
        "weights": [0.5, 0.5],
        "metrics": {
            "return_on_asset": {
                "lower_is_better": False,
                "thresholds": [
                    (0.15, float("inf")),
                    (0.10, 0.15),
                    (0.08, 0.10),
                    (0.06, 0.08),
                    (0.04, 0.06),
                    (0.02, 0.04),
                    (0.00, 0.02),
                    (-0.02, 0.00),
                    (float("-inf"), -0.02)
                ],
            },
            "asset_turnover": {
                "lower_is_better": False,
                "thresholds": [
                    (4.0, float("inf")),
                    (3.0, 4.0),
                    (2.0, 3.0),
                    (1.5, 2.0),
                    (1.0, 1.5),
                    (0.75, 1.0),
                    (0.5, 0.75),
                    (0.25, 0.5),
                    (float("-inf"), 0.25)
                ],
            },
        },
    },
}

# %%
model_metrics = [
    'oper_margin', 'tot_debt_to_tot_eqy', 'tot_debt_to_ebitda',
    'ebitda_to_tot_int_exp', 'return_on_asset', 'asset_turnover',
]

# %%
class CreditRatingCalculator:
    def __init__(self, metrics):
        self.metrics = metrics
        
    def _calculate_metric_score(self, metric, thresholds, inverse):
        for score, (lower, upper) in enumerate(thresholds, start=1):
            if (inverse and metric <= upper) or (not inverse and metric >= lower):
                return score
        return len(thresholds) // 2 # else return the middle score

    def _calculate_category_score(self, category_metrics, ratios):
        total_weighted_score = 0

        for metric, weight in zip(
            category_metrics["metrics"].items(), category_metrics["weights"]
        ):
            metric_name, metric_data = metric
            value = ratios[metric_name]
            score = self._calculate_metric_score(
                value, metric_data["thresholds"], metric_data["lower_is_better"]
            )
            total_weighted_score += score * weight

        return total_weighted_score

    def _calculate_scores(self, ratios):
        scores = {}
        for category, category_data in self.metrics.items():
            category_score = self._calculate_category_score(category_data, ratios)
            scores[category] = category_score
        return scores

    def _calculate_weighted_score(self, scores):
        weights = {
            category: category_data["class_weight"]
            for category, category_data in self.metrics.items()
        }
        return sum(scores[category] * weight for category, weight in weights.items())

    def _determine_credit_rating(self, weighted_score):
        credit_ratings = {
            "Aaa": 2.5,
            "Aa": 3.5,
            "A": 4.5,
            "Baa": 5.5,
            "Ba": 6.5,
            "B": 7.5,
            "Caa": 8.5,
            "Ca": 9.5,
            "C": float("inf")
        }
        return next(rating for rating, threshold in credit_ratings.items() if weighted_score <= threshold)

    def calculate_credit_rating(self, ratios):
        self.scores = self._calculate_scores(ratios)
        self.credit_score = self._calculate_weighted_score(self.scores)
        self.credit_rating = self._determine_credit_rating(self.credit_score)

# %%
def determine_credit_rating(weighted_score):
    credit_ratings = [
        (2.5, "Aaa"),
        (3.5, "Aa"),
        (4.5, "A"),
        (5.5, "Baa"),
        (6.5, "Ba"),
        (7.5, "B"),
        (8.5, "Caa"),
        (9.5, "Ca"),
        (10, "C"),
    ]

    for threshold, rating in credit_ratings:
        if weighted_score < threshold:
            return rating

# %%
features = pd.read_excel("dataset/features.xlsx", index_col=0)
targets = pd.read_excel("dataset/target.xlsx", index_col=0)
features.columns = features.columns.str.lower()

# %%
features
# Out:
#                  asset_turnover  bs_lt_borrow  bs_st_borrow  \
# AGL SJ Equity            0.4577  2.770832e+05    31777.2720
# ANG SJ Equity            0.5640  3.889976e+04     5113.5840
# ANH SJ Equity            0.2747  1.354406e+06    73124.2512
# BAW SJ Equity            0.8784  7.705000e+03     4142.0000
# BHG SJ Equity            0.5479  2.852730e+05   134871.0498
# ...                         ...           ...           ...
# UGPA3 BS Equity          3.3751  1.098727e+04     2304.6800
# USIM5 BS Equity          0.6896  5.855413e+03      167.9600
# VALE3 BS Equity          0.4576  6.246400e+04     4940.0000
# VAMO3 BS Equity          0.3247  1.083538e+04      881.6250
# VBBR3 BS Equity          3.8526  1.404800e+04     1470.0000
#
#                  bs_total_liabilities  bs_tot_asset  cfo_to_tot_debt  \
# AGL SJ Equity            6.378648e+05  1.215280e+06           0.3649
# ANG SJ Equity            8.099552e+04  1.492984e+05           0.4531
# ANH SJ Equity            2.313239e+06  4.005763e+06           0.1697
# BAW SJ Equity            3.130300e+04  4.812200e+04           0.1198
# BHG SJ Equity            9.921380e+05  1.904628e+06           0.8369
# ...                               ...           ...              ...
# UGPA3 BS Equity          2.422215e+04  3.825197e+04           0.2896
# USIM5 BS Equity          1.361231e+04  4.016175e+04           0.7852
# VALE3 BS Equity          2.576590e+05  4.559840e+05           0.9927
# VAMO3 BS Equity          1.607353e+04  2.080883e+04          -0.2292
# VBBR3 BS Equity          2.775000e+04  4.348100e+04           0.4114
#
#                       ebitda  ebitda_to_interest_expn  ebitda_to_revenue  \
# AGL SJ Equity    121616.1358                   4.7608            21.4962
# ANG SJ Equity     18864.5579                   9.6807            25.5943
# ANH SJ Equity    357280.8529                   5.0252            32.5985
# BAW SJ Equity      6624.0000                   4.1374            14.7108
# BHG SJ Equity    486944.0718                  32.0082            50.9114
# ...                      ...                      ...                ...
# UGPA3 BS Equity    5720.7110                   3.5200             4.5385
# USIM5 BS Equity    1592.4070                   2.3043             5.7616
# VALE3 BS Equity   85917.0000                  14.8800            41.2931
# VAMO3 BS Equity    2668.1330                   1.7422            43.8442
# VBBR3 BS Equity    7678.0000                   5.5277             4.7120
#
#                  ebitda_to_tot_int_exp  ...  return_on_cap  \
# AGL SJ Equity                   3.4697  ...         3.8440
# ANG SJ Equity                   9.6807  ...       -12.4486
# ANH SJ Equity                   4.9105  ...         5.8489
# BAW SJ Equity                   4.1374  ...        10.6581
# BHG SJ Equity                  24.3114  ...        21.8961
# ...                                ...  ...            ...
# UGPA3 BS Equity                 3.5200  ...        13.8756
# USIM5 BS Equity                 2.3043  ...         6.4728
# VALE3 BS Equity                14.6366  ...        16.9916
# VAMO3 BS Equity                 1.7422  ...        11.6270
# VBBR3 BS Equity                 5.5277  ...        18.9082
#
#                  return_on_inv_capital  sales_growth  sales_rev_turn  \
# AGL SJ Equity                   3.3318      -12.7171    5.657577e+05
# ANG SJ Equity                  -2.1459        1.7996    8.457203e+04
# ANH SJ Equity                   5.9292        2.7585    1.096003e+06
# BAW SJ Equity                   9.6124       14.3336    4.502800e+04
# BHG SJ Equity                  20.3470      -17.3293    9.564535e+05
# ...                                ...           ...             ...
# UGPA3 BS Equity                12.2053      -12.2436    1.260487e+05
# USIM5 BS Equity                 6.5389      -14.8817    2.763835e+04
# VALE3 BS Equity                23.7007       -8.1419    2.080660e+05
# VAMO3 BS Equity                11.4471       23.8534    6.085482e+03
# VBBR3 BS Equity                17.7104      -10.1953    1.629470e+05
#
#                  short_and_long_term_debt  total_equity  tot_debt_to_ebitda  \
# AGL SJ Equity                3.088605e+05  5.774149e+05              2.5667
# ANG SJ Equity                4.401335e+04  6.830287e+04              1.8845
# ANH SJ Equity                1.427530e+06  1.692523e+06              4.0381
# BAW SJ Equity                1.184700e+04  1.681900e+04              1.7885
# BHG SJ Equity                4.201441e+05  9.124902e+05              0.8155
# ...                                   ...           ...                 ...
# UGPA3 BS Equity              1.329195e+04  1.402983e+04              2.3235
# USIM5 BS Equity              6.023373e+03  2.654944e+04              3.7826
# VALE3 BS Equity              6.740400e+04  1.983250e+05              0.7845
# VAMO3 BS Equity              1.171701e+04  4.735295e+03              4.3915
# VBBR3 BS Equity              1.551800e+04  1.573100e+04              2.0211
#
#                  tot_debt_to_tot_asset  tot_debt_to_tot_cap  \
# AGL SJ Equity                  25.4148              34.8493
# ANG SJ Equity                  29.4801              39.1870
# ANH SJ Equity                  35.6369              45.7534
# BAW SJ Equity                  24.6187              41.3277
# BHG SJ Equity                  22.0591              31.5273
# ...                                ...                  ...
# UGPA3 BS Equity                34.7484              48.6497
# USIM5 BS Equity                14.9978              18.4920
# VALE3 BS Equity                14.7821              25.3657
# VAMO3 BS Equity                56.3079              71.2180
# VBBR3 BS Equity                35.6892              49.6592
#
#                  tot_debt_to_tot_eqy
# AGL SJ Equity                53.4902
# ANG SJ Equity                64.4385
# ANH SJ Equity                84.3433
# BAW SJ Equity                70.4382
# BHG SJ Equity                46.0437
# ...                              ...
# UGPA3 BS Equity              94.7407
# USIM5 BS Equity              22.6874
# VALE3 BS Equity              33.9866
# VAMO3 BS Equity             247.4399
# VBBR3 BS Equity              98.6460
#
# [70 rows x 26 columns]

# %%
ft = pd.read_excel("dataaa.xlsx", index_col=0, parse_dates=True)
# Out:
# C:\Users\Thabang Ndhlovu\AppData\Local\Temp\ipykernel_772\536687646.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ft = pd.read_excel("dataaa.xlsx", index_col=0, parse_dates=True)

# %%
import joblib
import pandas as pd

study = {}
studies = {}

for company in features.index:
    ratios = features.loc[company][model_metrics].to_dict()    
    model = CreditRatingCalculator(model_inputs)
    model.calculate_credit_rating(ratios)
    
    # if company in tickers:
    #     credit_score = tree_model.predict(features.loc[company, model_metrics].to_frame().T).round(1)[0]
    #     credit_rating = determine_credit_rating(credit_score)
    # else:
    credit_score = model.credit_score
    credit_rating = model.credit_rating
    
    study[company] = {"model_class_scores": model.scores, "model_credit_scores": credit_score, "model_credit_ratings": credit_rating}
    studies[company] = {"model_inputs": ratios}
studies = pd.DataFrame(studies).T

# %%
study_df = studies.copy()

# %%
ba = study_df.iloc[:99]

# %%
b = pd.concat([ft, ba])

# %%
b = pd.read_excel("results.xlsx",index_col=0)

# %%
b = b.join(ba)

# %%
b.columns = b.columns.str.lower()

# %%
b.to_excel("results2.xlsx")

# %%
b
# Out:
#                            security_name        gics_sector_name  \
# BLU SJ Equity    Blue Label Telecoms Ltd  Communication Services
# MCG SJ Equity          MultiChoice Group  Communication Services
# MTN SJ Equity              MTN Group Ltd  Communication Services
# TKG SJ Equity          Telkom SA SOC Ltd  Communication Services
# VOD SJ Equity          Vodacom Group Ltd  Communication Services
# ...                                  ...                     ...
# VBBR3 BS Equity         Vibra Energia SA  Consumer Discretionary
# VIVA3 BS Equity  Vivara Participacoes SA  Consumer Discretionary
# VIVT3 BS Equity     Telefonica Brasil SA  Communication Services
# WEGE3 BS Equity                   WEG SA             Industrials
# YDUQ3 BS Equity   YDUQS Participacoes SA  Consumer Discretionary
#
#                 model_credit_ratings  model_credit_scores  \
# BLU SJ Equity                    Baa                5.365
# MCG SJ Equity                     Ba                5.880
# MTN SJ Equity                    Baa                4.960
# TKG SJ Equity                     Ba                5.890
# VOD SJ Equity                      A                4.345
# ...                              ...                  ...
# VBBR3 BS Equity                    B                6.720
# VIVA3 BS Equity                  Baa                4.685
# VIVT3 BS Equity                    A                4.015
# WEGE3 BS Equity                   Aa                3.405
# YDUQ3 BS Equity                    B                6.690
#
#                                                 model_class_scores  \
# BLU SJ Equity    {'profitability': 9.0, 'leverage_coverage': 4....
# MCG SJ Equity    {'profitability': 6.0, 'leverage_coverage': 6....
# MTN SJ Equity    {'profitability': 5.0, 'leverage_coverage': 5....
# TKG SJ Equity    {'profitability': 7.0, 'leverage_coverage': 5....
# VOD SJ Equity    {'profitability': 4.0, 'leverage_coverage': 4....
# ...                                                            ...
# VBBR3 BS Equity  {'profitability': 9.0, 'leverage_coverage': 6....
# VIVA3 BS Equity  {'profitability': 5.0, 'leverage_coverage': 4....
# VIVT3 BS Equity  {'profitability': 6.0, 'leverage_coverage': 2....
# WEGE3 BS Equity  {'profitability': 6.0, 'leverage_coverage': 2....
# YDUQ3 BS Equity  {'profitability': 6.0, 'leverage_coverage': 7....
#
#                 rsk_bb_issuer_default  bb_5y_default_prob rtg_moody_long_term  \
# BLU SJ Equity                     HY1            0.074174                 NaN
# MCG SJ Equity                     IG7            0.024876                 NaN
# MTN SJ Equity                     IG7            0.020231                 Ba2
# TKG SJ Equity                     HY2            0.066731                 Ba2
# VOD SJ Equity                     IG2            0.007515                 NaN
# ...                               ...                 ...                 ...
# VBBR3 BS Equity                   IG5            0.013553                 Ba1
# VIVA3 BS Equity                   IG4            0.015635                 NaN
# VIVT3 BS Equity                   IG1            0.002467                 NaN
# WEGE3 BS Equity                   IG1            0.000725                 NaN
# YDUQ3 BS Equity                   HY2            0.077653                 NaN
#
#                 rtg_moody_long_term_date rtg_sp_lt_lc_issuer_credit  \
# BLU SJ Equity                        NaN                        NaN
# MCG SJ Equity                        NaN                        NaN
# MTN SJ Equity                 2022/04/06                        BB-
# TKG SJ Equity                 2023/12/19                         BB
# VOD SJ Equity                        NaN                        NaN
# ...                                  ...                        ...
# VBBR3 BS Equity               2021/05/18                        NaN
# VIVA3 BS Equity                      NaN                        NaN
# VIVT3 BS Equity                      NaN                        NaN
# WEGE3 BS Equity                      NaN                        NaN
# YDUQ3 BS Equity                      NaN                        NaN
#
#                 rtg_sp_lt_lc_iss_cred_rtg_dt country_full_name  \
# BLU SJ Equity                            NaN      SOUTH AFRICA
# MCG SJ Equity                            NaN      SOUTH AFRICA
# MTN SJ Equity                     2020/05/12      SOUTH AFRICA
# TKG SJ Equity                     2020/05/12      SOUTH AFRICA
# VOD SJ Equity                            NaN      SOUTH AFRICA
# ...                                      ...               ...
# VBBR3 BS Equity                          NaN            BRAZIL
# VIVA3 BS Equity                          NaN            BRAZIL
# VIVT3 BS Equity                          NaN            BRAZIL
# WEGE3 BS Equity                          NaN            BRAZIL
# YDUQ3 BS Equity                          NaN            BRAZIL
#
#                  book_val_per_sh  \
# BLU SJ Equity           5.296074
# MCG SJ Equity          13.086630
# MTN SJ Equity          77.065739
# TKG SJ Equity          51.835067
# VOD SJ Equity          47.916122
# ...                          ...
# VBBR3 BS Equity        14.109023
# VIVA3 BS Equity         8.221579
# VIVT3 BS Equity        42.095769
# WEGE3 BS Equity         4.133758
# YDUQ3 BS Equity        10.442080
#
#                                                       model_inputs
# BLU SJ Equity                                                  NaN
# MCG SJ Equity                                                  NaN
# MTN SJ Equity                                                  NaN
# TKG SJ Equity                                                  NaN
# VOD SJ Equity                                                  NaN
# ...                                                            ...
# VBBR3 BS Equity  {'oper_margin': 4.371973709242882, 'tot_debt_t...
# VIVA3 BS Equity  {'oper_margin': 20.605913188911963, 'tot_debt_...
# VIVT3 BS Equity  {'oper_margin': 15.217873360866074, 'tot_debt_...
# WEGE3 BS Equity  {'oper_margin': 19.88091104121048, 'tot_debt_t...
# YDUQ3 BS Equity  {'oper_margin': 15.630059433961167, 'tot_debt_...
#
# [223 rows x 14 columns]

# %%
df =  pd.read_excel("results2 - Copy.xlsx", index_col=0)
ft = pd.read_excel("dataset/ibx_jalsh_features.xlsx", index_col=0)

# %%
a = df[["rtg_moody_long_term"]].dropna().index.to_list()
b = df[["rtg_sp_lt_lc_issuer_credit"]].dropna().index.to_list()

stocks = list(np.unique([a + b]))

# %%
study =df.loc[stocks]

# %%
n = ft.loc[ft.index[ft.index.isin(stocks)]]

# %%
d = n.dropna()

# %%
val = d.index.to_list()

# %%
dd = df.loc[val]

# %%
dd.sort_values(["country_full_name"])
# Out:
#                                    security_name        gics_sector_name  \
# MTN SJ Equity                      MTN Group Ltd  Communication Services
# TKG SJ Equity                  Telkom SA SOC Ltd  Communication Services
# CYRE3 BS Equity   Cyrela Brazil Realty SA Empree  Consumer Discretionary
# VBBR3 BS Equity                 Vibra Energia SA  Consumer Discretionary
# PPH SJ Equity                Pepkor Holdings Ltd  Consumer Discretionary
# CFR SJ Equity        Cie Financiere Richemont SA  Consumer Discretionary
# ANH SJ Equity         Anheuser-Busch InBev SA/NV        Consumer Staples
# ABEV3 BS Equity                         Ambev SA        Consumer Staples
# BEEF3 BS Equity                Minerva SA/Brazil        Consumer Staples
# BRFS3 BS Equity                           BRF SA        Consumer Staples
# MRFG3 BS Equity          Marfrig Global Foods SA        Consumer Staples
# SMTO3 BS Equity                 Sao Martinho S/A        Consumer Staples
# BTI SJ Equity       British American Tobacco PLC        Consumer Staples
# CSAN3 BS Equity                         Cosan SA                  Energy
# PETR3 BS Equity           Petroleo Brasileiro SA                  Energy
# PETR4 BS Equity           Petroleo Brasileiro SA                  Energy
# PRIO3 BS Equity                   PRIO SA/Brazil                  Energy
# RAIZ4 BS Equity                        Raizen SA                  Energy
# RRRP3 BS Equity       3R PETROLEUM OLEO E GAS SA                  Energy
# UGPA3 BS Equity        Ultrapar Participacoes SA                  Energy
# B3SA3 BS Equity      B3 SA - Brasil Bolsa Balcao              Financials
# BPAC11 BS Equity            Banco BTG Pactual SA              Financials
# CIEL3 BS Equity                         Cielo SA              Financials
# HYPE3 BS Equity                        Hypera SA             Health Care
# RDOR3 BS Equity            Rede D'Or Sao Luiz SA             Health Care
# ECOR3 BS Equity   EcoRodovias Infraestrutura e L             Industrials
# EMBR3 BS Equity                       Embraer SA             Industrials
# MOVI3 BS Equity          Movida Participacoes SA             Industrials
# RAIL3 BS Equity                          Rumo SA             Industrials
# RENT3 BS Equity           Localiza Rent a Car SA             Industrials
# VAMO3 BS Equity   Vamos Locacao de Caminhoes Maq             Industrials
# BVT SJ Equity              Bidvest Group Ltd/The             Industrials
# BHG SJ Equity                      BHP Group Ltd               Materials
# S32 SJ Equity                        South32 Ltd               Materials
# ANG SJ Equity                     Baa                4.674
# MNP SJ Equity                     Baa                4.885
# GFI SJ Equity                       A                4.820
# SAP SJ Equity                      Ba                5.915
# SOL SJ Equity                     Baa                4.820
# SSW SJ Equity                      Ba                5.835
# GLN SJ Equity                     Baa                4.680
# MULT3 BS Equity                     A                4.350
# NRP SJ Equity                     Baa                4.680
# CMIG4 BS Equity                   Baa                4.985
# ELET3 BS Equity                    Ba                5.665
# ELET6 BS Equity                    Ba                5.665
# ENGI11 BS Equity                    B                6.630
# SBSP3 BS Equity                    Ba                5.530
# TAEE11 BS Equity                   Ba                5.670
#
#                                                  model_class_scores  \
# MTN SJ Equity     {'profitability': 5.0, 'leverage_coverage': 5....
# TKG SJ Equity     {'profitability': 7.0, 'leverage_coverage': 5....
# CYRE3 BS Equity   {'profitability': 7.0, 'leverage_coverage': 7....
# VBBR3 BS Equity   {'profitability': 9.0, 'leverage_coverage': 6....
# PPH SJ Equity     {'profitability': 8.0, 'leverage_coverage': 5....
# CFR SJ Equity     {'profitability': 6.0, 'leverage_coverage': 3....
# ANH SJ Equity     {'profitability': 4.0, 'leverage_coverage': 4....
# ABEV3 BS Equity   {'profitability': 5.0, 'leverage_coverage': 2....
# BEEF3 BS Equity   {'profitability': 8.0, 'leverage_coverage': 8....
# BRFS3 BS Equity   {'profitability': 9.0, 'leverage_coverage': 8....
# MRFG3 BS Equity   {'profitability': 9.0, 'leverage_coverage': 8....
# SMTO3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 7....
# BTI SJ Equity     {'profitability': 4.0, 'leverage_coverage': 7....
# CSAN3 BS Equity   {'profitability': 6.0, 'leverage_coverage': 8....
# PETR3 BS Equity   {'profitability': 2.0, 'leverage_coverage': 5....
# PETR4 BS Equity   {'profitability': 2.0, 'leverage_coverage': 5....
# PRIO3 BS Equity   {'profitability': 1.0, 'leverage_coverage': 5....
# RAIZ4 BS Equity   {'profitability': 9.0, 'leverage_coverage': 7....
# RRRP3 BS Equity   {'profitability': 5.0, 'leverage_coverage': 8....
# UGPA3 BS Equity   {'profitability': 9.0, 'leverage_coverage': 7....
# B3SA3 BS Equity   {'profitability': 1.0, 'leverage_coverage': 6....
# BPAC11 BS Equity  {'profitability': 1.0, 'leverage_coverage': 8....
# CIEL3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 6....
# HYPE3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 6....
# RDOR3 BS Equity   {'profitability': 7.0, 'leverage_coverage': 8....
# ECOR3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 8....
# EMBR3 BS Equity   {'profitability': 8.0, 'leverage_coverage': 8....
# MOVI3 BS Equity   {'profitability': 7.0, 'leverage_coverage': 8....
# RAIL3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 8....
# RENT3 BS Equity   {'profitability': 5.0, 'leverage_coverage': 8....
# VAMO3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 8....
# BVT SJ Equity     {'profitability': 8.0, 'leverage_coverage': 6....
# BHG SJ Equity     {'profitability': 4.0, 'leverage_coverage': 4....
# S32 SJ Equity     {'profitability': 8.0, 'leverage_coverage': 4....
# BRKM5 BS Equity   {'profitability': 9.0, 'leverage_coverage': 8....
# CSNA3 BS Equity   {'profitability': 7.0, 'leverage_coverage': 7....
# GGBR4 BS Equity   {'profitability': 7.0, 'leverage_coverage': 3....
# KLBN11 BS Equity  {'profitability': 5.0, 'leverage_coverage': 8....
# SUZB3 BS Equity   {'profitability': 1.0, 'leverage_coverage': 7....
# USIM5 BS Equity   {'profitability': 9.0, 'leverage_coverage': 5....
# VALE3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 4....
# AGL SJ Equity     {'profitability': 6.0, 'leverage_coverage': 5....
# ANG SJ Equity     {'profitability': 8.0, 'leverage_coverage': 5....
# MNP SJ Equity     {'profitability': 8.0, 'leverage_coverage': 3....
# GFI SJ Equity     {'profitability': 4.0, 'leverage_coverage': 3....
# SAP SJ Equity     {'profitability': 8.0, 'leverage_coverage': 5....
# SOL SJ Equity     {'profitability': 6.0, 'leverage_coverage': 4....
# SSW SJ Equity     {'profitability': 4.0, 'leverage_coverage': 7....
# GLN SJ Equity     {'profitability': 7.0, 'leverage_coverage': 3....
# MULT3 BS Equity   {'profitability': 1.0, 'leverage_coverage':
# BEEF3 BS Equity             BRAZIL         0.297169
# BRFS3 BS Equity             BRAZIL         8.890105
# MRFG3 BS Equity             BRAZIL         8.213386
# SMTO3 BS Equity             BRAZIL        18.303256
# BTI SJ Equity              BRITAIN        23.504655
# CSAN3 BS Equity             BRAZIL         9.896381
# PETR3 BS Equity             BRAZIL        29.400075
# PETR4 BS Equity             BRAZIL        29.400075
# PRIO3 BS Equity             BRAZIL        16.630087
# RAIZ4 BS Equity             BRAZIL         2.170794
# RRRP3 BS Equity             BRAZIL        22.886592
# UGPA3 BS Equity             BRAZIL        12.289614
# B3SA3 BS Equity             BRAZIL         3.612297
# BPAC11 BS Equity            BRAZIL        12.875358
# CIEL3 BS Equity             BRAZIL         4.552564
# HYPE3 BS Equity             BRAZIL        18.176598
# RDOR3 BS Equity             BRAZIL         9.997179
# ECOR3 BS Equity             BRAZIL         3.936030
# EMBR3 BS Equity             BRAZIL        18.363335
# MOVI3 BS Equity             BRAZIL         7.049402
# RAIL3 BS Equity             BRAZIL         8.473274
# RENT3 BS Equity             BRAZIL        24.006927
# VAMO3 BS Equity             BRAZIL         4.318818
# BVT SJ Equity         SOUTH AFRICA       100.080076
# BHG SJ Equity            AUSTRALIA              NaN
# S32 SJ Equity            AUSTRALIA              NaN
# BRKM5 BS Equity             BRAZIL         5.007477
# CSNA3 BS Equity             BRAZIL        13.197161
# GGBR4 BS Equity             BRAZIL        28.041344
# KLBN11 BS Equity            BRAZIL              NaN
# SUZB3 BS Equity             BRAZIL        34.662970
# USIM5 BS Equity             BRAZIL        19.379985
# VALE3 BS Equity             BRAZIL        44.411970
# AGL SJ Equity              BRITAIN        20.668427
# ANG SJ Equity              BRITAIN         8.865255
# MNP SJ Equity              BRITAIN              NaN
# GFI SJ Equity         SOUTH AFRICA         5.009396
# SAP SJ Equity         SOUTH AFRICA         4.038221
# SOL SJ Equity         SOUTH AFRICA       309.864959
# SSW SJ Equity         SOUTH AFRICA        17.215632
# GLN SJ Equity          SWITZERLAND              NaN
# MULT3 BS Equity             BRAZIL        11.912980
# NRP SJ Equity          NETHERLANDS         6.514212
# CMIG4 BS Equity             BRAZIL        11.201527
# ELET3 BS Equity             BRAZIL        49.916010
# ELET6 BS Equity             BRAZIL        49.916010
# ENGI11 BS Equity            BRAZIL         5.836885
# SBSP3 BS Equity             BRAZIL        43.682436
# TAEE11 BS Equity            BRAZIL        19.388480

# %%
df = dd.reset_index()

# %%
df['Sort_Key'] = df['index'].apply(lambda x: x.split()[1])

# %%
df_sorted = df.sort_values(by=['Sort_Key'], ascending=False)

# %%
df_sorted = df_sorted.drop(["Sort_Key"], axis=1)

# %%
df = df_sorted.set_index("index")

# %%
import json

# %%
with open("hello_credit_config.json", "r") as f:
    file = json.load(f)

# %%
mappings = file['credit_rating_mappings']

# %%
import json

with open("hello_credit_config.json", "r") as f:
    file = json.load(f)
    
mappings = file['credit_rating_mappings']

# Invert the dictionary
invert_dict = {v: k for k, vals in mappings.items() for v in vals}

df['rtg_moody_long_term'] = df['rtg_moody_long_term'].map(invert_dict)
df['rtg_sp_lt_lc_issuer_credit'] = df['rtg_sp_lt_lc_issuer_credit'].map(invert_dict)
df['rsk_bb_issuer_default'] = df['rsk_bb_issuer_default'].map(invert_dict)

# %%
df['rtg_moody_long_term'] = df['rtg_moody_long_term'].map(invert_dict)
df['rtg_sp_lt_lc_issuer_credit'] = df['rtg_sp_lt_lc_issuer_credit'].map(invert_dict)
df['rsk_bb_issuer_default'] = df['rsk_bb_issuer_default'].map(invert_dict)

# %%
df['rtg_sp_lt_lc_issuer_credit'] = df['rtg_sp_lt_lc_issuer_credit'].map(invert_dict)
df['rsk_bb_issuer_default'] = df['rsk_bb_issuer_default'].map(invert_dict)

# %%
df['rsk_bb_issuer_default'] = df['rsk_bb_issuer_default'].map(invert_dict)

# %%
c = file['credit_rating_scale']

# %%
df['']

# %%
df['rtg_moody_long_term'] = df['rtg_moody_long_term'].map(c)

# %%
df['rsk_bb_issuer_default']= df['rsk_bb_issuer_default'].map(c)

# %%
df['model_credit_ratings'] = df['model_credit_ratings'].map(c)

# %%
df.to_excel("demo2.xlsx")

# %%
df = df.sort_values(["gics_sector_name", "country_full_name", "model_credit_ratings","rtg_moody_long_term", "rtg_sp_lt_lc_issuer_credit"])

# %%
df.to_excel("demo3.xlsx")

# %%
df
# Out:
#                                    security_name        gics_sector_name  \
# index
# TKG SJ Equity                  Telkom SA SOC Ltd  Communication Services
# GLN SJ Equity                       Glencore PLC               Materials
# AGL SJ Equity                 Anglo American PLC               Materials
# ANG SJ Equity              Anglogold Ashanti Plc               Materials
# ANH SJ Equity         Anheuser-Busch InBev SA/NV        Consumer Staples
# BHG SJ Equity                      BHP Group Ltd               Materials
# BVT SJ Equity              Bidvest Group Ltd/The             Industrials
# CFR SJ Equity        Cie Financiere Richemont SA  Consumer Discretionary
# GFI SJ Equity                    Gold Fields Ltd               Materials
# BTI SJ Equity       British American Tobacco PLC        Consumer Staples
# MNP SJ Equity                          Mondi PLC               Materials
# NRP SJ Equity                 NEPI Rockcastle NV             Real Estate
# PPH SJ Equity                Pepkor Holdings Ltd  Consumer Discretionary
# S32 SJ Equity                        South32 Ltd               Materials
# SAP SJ Equity                          Sappi Ltd               Materials
# SOL SJ Equity                          Sasol Ltd               Materials
# SSW SJ Equity             Sibanye Stillwater Ltd               Materials
# MTN SJ Equity                      MTN Group Ltd  Communication Services
# UGPA3 BS Equity        Ultrapar Participacoes SA                  Energy
# SMTO3 BS Equity                 Sao Martinho S/A        Consumer Staples
# SUZB3 BS Equity                        Suzano SA               Materials
# TAEE11 BS Equity  Transmissora Alianca de Energi               Utilities
# VBBR3 BS Equity                 Vibra Energia SA  Consumer Discretionary
# USIM5 BS Equity   Usinas Siderurgicas de Minas G               Materials
# VALE3 BS Equity                          Vale SA               Materials
# VAMO3 BS Equity   Vamos Locacao de Caminhoes Maq             Industrials
# RRRP3 BS Equity       3R PETROLEUM OLEO E GAS SA                  Energy
# SBSP3 BS Equity   Cia de Saneamento Basico do Es               Utilities
# ABEV3 BS Equity                         Ambev SA        Consumer Staples
# BRFS3 BS Equity                    8.5                8.445
# BRKM5 BS Equity                    9.5                8.610
# CIEL3 BS Equity                    5.5                4.950
# CMIG4 BS Equity                    5.5                4.985
# CSAN3 BS Equity                    8.5                7.695
# CSNA3 BS Equity                    8.5                7.590
# CYRE3 BS Equity                    7.5                6.955
# ECOR3 BS Equity                    6.5                6.195
# ELET3 BS Equity                    6.5                5.665
# ELET6 BS Equity                    6.5                5.665
# EMBR3 BS Equity                    8.5                7.695
# ENGI11 BS Equity                   7.5                6.630
# GGBR4 BS Equity                    5.5                4.660
# HYPE3 BS Equity                    5.5                5.315
# KLBN11 BS Equity                   7.5                6.630
# MOVI3 BS Equity                    8.5                7.830
# MRFG3 BS Equity                    8.5                8.370
# MULT3 BS Equity                    4.5                4.350
# PETR3 BS Equity                    4.5                4.445
# PETR4 BS Equity                    4.5                4.445
# PRIO3 BS Equity                    4.5                3.980
# RAIL3 BS Equity                    6.5                6.105
# RAIZ4 BS Equity                    7.5                7.200
# RENT3 BS Equity                    7.5                6.630
#
#                                                  model_class_scores  \
# index
# TKG SJ Equity     {'profitability': 7.0, 'leverage_coverage': 5....
# GLN SJ Equity     {'profitability': 7.0, 'leverage_coverage': 3....
# AGL SJ Equity     {'profitability': 6.0, 'leverage_coverage': 5....
# ANG SJ Equity     {'profitability': 8.0, 'leverage_coverage': 5....
# ANH SJ Equity     {'profitability': 4.0, 'leverage_coverage': 4....
# BHG SJ Equity     {'profitability': 4.0, 'leverage_coverage': 4....
# BVT SJ Equity     {'profitability': 8.0, 'leverage_coverage': 6....
# CFR SJ Equity     {'profitability': 6.0, 'leverage_coverage': 3....
# GFI SJ Equity     {'profitability': 4.0, 'leverage_coverage': 3....
# BTI SJ Equity     {'profitability': 4.0, 'leverage_coverage': 7....
# MNP SJ Equity     {'profitability': 8.0, 'leverage_coverage': 3....
# NRP SJ Equity     {'profitability': 1.0, 'leverage_coverage': 6....
# PPH SJ Equity     {'profitability': 8.0, 'leverage_coverage': 5....
# S32 SJ Equity     {'profitability': 8.0, 'leverage_coverage': 4....
# SAP SJ Equity     {'profitability': 8.0, 'leverage_coverage': 5....
# SOL SJ Equity     {'profitability': 6.0, 'leverage_coverage': 4....
# SSW SJ Equity     {'profitability': 4.0, 'leverage_coverage': 7....
# MTN SJ Equity     {'profitability': 5.0, 'leverage_coverage': 5....
# UGPA3 BS Equity   {'profitability': 9.0, 'leverage_coverage': 7....
# SMTO3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 7....
# SUZB3 BS Equity   {'profitability': 1.0, 'leverage_coverage': 7....
# TAEE11 BS Equity  {'profitability': 1.0, 'leverage_coverage': 8....
# VBBR3 BS Equity   {'profitability': 9.0, 'leverage_coverage': 6....
# USIM5 BS Equity   {'profitability': 9.0, 'leverage_coverage': 5....
# VALE3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 4....
# VAMO3 BS Equity   {'profitability': 3.0, 'leverage_coverage': 8....
# RRRP3 BS Equity   {'profitability': 5.0, 'leverage_coverage': 8....
# SBSP3 BS Equity   {'profitability': 5.0, 'leverage_coverage': 6....
# ABEV3 BS Equity   {'profitability': 5.0, 'leverage_coverage': 2....
# B3SA3 BS Equity   {'profitability': 1.0, 'leverage_coverage': 6....
# RDOR3 BS Equity   {'profitability': 7.0, 'leverage_coverage': 8....
# BEEF3 BS Equity   {'profitability': 8.0, 'leverage_coverage': 8....
# BPAC11 BS Equity  {'profitability': 1.0, 'leverage_coverage': 8....
# BRFS3 BS Equity   {'profitability': 9.0, 'leverage_coverage': 8....
# BRKM5 BS Equity   {'profitability': 9.0, 'leverage_coverage': 8....
# CIEL3 BS Equity   {'profitability': 3.0, 'leverage_coverage':
# PRIO3 BS Equity                          6.5                   2023/01/27
# RAIL3 BS Equity                          6.5                   2023/12/20
# RAIZ4 BS Equity                          5.5                   2023/12/20
# RENT3 BS Equity                          5.5                   2023/12/20
#
#                  country_full_name  book_val_per_sh
# index
# TKG SJ Equity         SOUTH AFRICA        51.835067
# GLN SJ Equity          SWITZERLAND              NaN
# AGL SJ Equity              BRITAIN        20.668427
# ANG SJ Equity              BRITAIN         8.865255
# ANH SJ Equity              BELGIUM              NaN
# BHG SJ Equity            AUSTRALIA              NaN
# BVT SJ Equity         SOUTH AFRICA       100.080076
# CFR SJ Equity          SWITZERLAND              NaN
# GFI SJ Equity         SOUTH AFRICA         5.009396
# BTI SJ Equity              BRITAIN        23.504655
# MNP SJ Equity              BRITAIN              NaN
# NRP SJ Equity          NETHERLANDS         6.514212
# PPH SJ Equity         SOUTH AFRICA        16.046087
# S32 SJ Equity            AUSTRALIA              NaN
# SAP SJ Equity         SOUTH AFRICA         4.038221
# SOL SJ Equity         SOUTH AFRICA       309.864959
# SSW SJ Equity         SOUTH AFRICA        17.215632
# MTN SJ Equity         SOUTH AFRICA        77.065739
# UGPA3 BS Equity             BRAZIL        12.289614
# SMTO3 BS Equity             BRAZIL        18.303256
# SUZB3 BS Equity             BRAZIL        34.662970
# TAEE11 BS Equity            BRAZIL        19.388480
# VBBR3 BS Equity             BRAZIL        14.109023
# USIM5 BS Equity             BRAZIL        19.379985
# VALE3 BS Equity             BRAZIL        44.411970
# VAMO3 BS Equity             BRAZIL         4.318818
# RRRP3 BS Equity             BRAZIL        22.886592
# SBSP3 BS Equity             BRAZIL        43.682436
# ABEV3 BS Equity             BRAZIL         5.014099
# B3SA3 BS Equity             BRAZIL         3.612297
# RDOR3 BS Equity             BRAZIL         9.997179
# BEEF3 BS Equity             BRAZIL         0.297169
# BPAC11 BS Equity            BRAZIL        12.875358
# BRFS3 BS Equity             BRAZIL         8.890105
# BRKM5 BS Equity             BRAZIL         5.007477
# CIEL3 BS Equity             BRAZIL         4.552564
# CMIG4 BS Equity             BRAZIL        11.201527
# CSAN3 BS Equity             BRAZIL         9.896381
# CSNA3 BS Equity             BRAZIL        13.197161
# CYRE3 BS Equity             BRAZIL        20.511897
# ECOR3 BS Equity             BRAZIL         3.936030
# ELET3 BS Equity             BRAZIL        49.916010
# ELET6 BS Equity             BRAZIL        49.916010
# EMBR3 BS Equity             BRAZIL        18.363335
# ENGI11 BS Equity            BRAZIL         5.836885
# GGBR4 BS Equity             BRAZIL        28.041344
# HYPE3 BS Equity             BRAZIL        18.176598
# KLBN11 BS Equity            BRAZIL              NaN
# MOVI3 BS Equity             BRAZIL         7.049402
# MRFG3 BS Equity             BRAZIL         8.213386
# MULT3 BS Equity             BRAZIL        11.912980
# PETR3 BS Equity             BRAZIL        29.400075
# PETR4 BS Equity             BRAZIL        29.400075
# PRIO3 BS Equity             BRAZIL        16.630087
# RAIL3 BS Equity             BRAZIL         8.473274
# RAIZ4 BS Equity             BRAZIL         2.170794
# RENT3 BS Equity             BRAZIL        24.006927
