# %%
import pandas as pd

# %%
def get_nested_dict(file_path):
    data = pd.read_excel(file_path, index_col=[0, 1])
    nested_dict = {}

    for (category, metric), values in data.iterrows():
        if category not in nested_dict:
            nested_dict[category] = {}
        nested_dict[category][metric] = values.tolist()

    return nested_dict

# %%
get_nested_dict("COL AT Equity.xlsx")
# Out:
# {'leverage_coverage_metrics': {'debt_to_equity': [nan,
#    nan,
#    0.0,
#    43.4899,
#    399.1205,
#    351.8663,
#    312.9321,
#    267.1931,
#    278.3799,
#    38.0337,
#    0.0,
#    43.4899,
#    399.1205,
#    351.8663,
#    312.9321,
#    267.1931,
#    278.3799,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan],
#   'debt_to_ebitda': [nan,
#    nan,
#    0.0,
#    0.6948,
#    3.1986,
#    2.8798,
#    2.8711,
#    2.6143,
#    2.7384,
#    1.0335,
#    0.0,
#    0.6948,
#    3.1986,
#    2.8798,
#    2.8711,
#    2.6143,
#    2.7384,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan],
#   'ebitda_to_interest_expense': [nan,
#    nan,
#    nan,
#    61.4415,
#    7.5708,
#    8.322,
#    9.9853,
#    9.2453,
#    8.9465,
#    10.5643,
#    10.5643,
#    61.4415,
#    7.5708,
#    8.322,
#    9.9853,
#    9.2453,
#    8.9465,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan]},
#  'efficiency_metrics': {'asset_turnover': [nan,
#    nan,
#    nan,
#    3.4464,
#    2.6868,
#    2.1349,
#    2.0748,
#    2.1865,
#    2.2894,
#    3.6792,
#    3.6792,
#    3.4464,
#    2.6868,
#    2.1349,
#    2.0748,
#    2.1865,
#    2.2894,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan]},
#  'profitability_metrics': {'ebitda_margin': [4.5435,
#    3.8901,
#    3.7376,
#    3.8002,
#    4.6792,
#    4.8238,
#    4.7834,
#    4.6119,
#    4.75,
#    3.8901,
#    3.7376,
#    3.8002,
#    4.6792,
#    4.8238,
#    4.7834,
#    4.6119,
#    4.75,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan],
#   'return_on_assets': [nan,
#    nan,
#    nan,
#    12.8548,
#    6.9544,
#    5.5111,
#    5.6711,
#    5.9147,
#    5.8592,
#    7.9315,
#    7.9315,
#    12.8548,
#    6.9544,
#    5.5111,
#    5.6711,
#    5.9147,
#    5.8592,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan,
#    nan]}}
