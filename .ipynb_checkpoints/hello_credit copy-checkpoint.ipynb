# %% [markdown]
# # **Predictive Default Risk Assessor V.01**

# %% [markdown]
# # TODO
#
# * Base model
# * Comparison
# * Specialised
# * For small entities - Examples?
# * Backtest - All sectors
# * Understanding the model across all sectors/industries
# * Any markets - consumer goods, industries
# * UI last step after backtesting

# %%
import json

import numpy as np
import pandas as pd

from collections import namedtuple
from sklearn.metrics import mean_squared_error, root_mean_squared_error, accuracy_score, mean_absolute_percentage_error
from dataclasses import dataclass
from quantstats import * 
extend_pandas()

# %%
MAPPED_RATINGS = [
    ("Aaa", 2.5),
    ("Aa", 3.5),
    ("A", 4.5),
    ("Baa", 5.5),
    ("Ba", 6.5),
    ("B", 7.5),
    ("Caa", 8.5),
    ("Ca", 9.5),
    ("C", float("inf")),
]

# %%
with open("metrics.json", "r") as f:
    metrics = json.load(f)

# %%
df = pd.read_excel("creditwatch_small_medium_company_template.xlsx", index_col=[0, 1])
nested_dict = get_expected_metrics(get_nested_dict(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 df = pd.read_excel("creditwatch_small_medium_company_template.xlsx", index_col=[0, 1])
# ----> 2 nested_dict = get_expected_metrics(get_nested_dict(df))
#
# NameError: name 'get_expected_metrics' is not defined

# %%
def calculate_credit_rating(metrics, ratios):
    calculation_details = {"metrics": {}}

    def determine_credit_rating(score):
        for rating, threshold in MAPPED_RATINGS:
            if score <= threshold:
                return rating
        return len(MAPPED_RATINGS) // 2  # Return the middile rating if no threshold is met

    def calculate_metric_score(value, thresholds, lower_is_better):
        for score, (lower, upper) in enumerate(thresholds, start=1):
            if lower_is_better and value <= upper or not lower_is_better and value >= lower:
                return score
        return len(thresholds) // 2

    def calculate_category_score(category, category_data):
        category_ratios = ratios[category]
        metric_weights = category_data["metric_weights"]
        total_weighted_score = 0

        for metric_name, metric_data in category_data["metrics"].items():
            value = category_ratios[metric_name]
            score = calculate_metric_score(value, metric_data["thresholds"], metric_data["lower_is_better"])
            
            weight = metric_weights[metric_name]
            weighted_score = score * weight
            
            rating = determine_credit_rating(score)
            total_weighted_score += weighted_score
            calculation_details["metrics"][metric_name] = {
                "category": category,
                "value": value,
                "score": score,
                "weight": weight,
                "weighted_score": weighted_score,
                "rating": rating,
            }
        return total_weighted_score

    scores = {category: calculate_category_score(category, category_data)
              for category, category_data in metrics.items()}

    total_weighted_score = sum(
        scores[category] * category_data["class_weight"]
        for category, category_data in metrics.items()
    )
    total_weight = sum(category_data["class_weight"] for category_data in metrics.values())
    credit_score = total_weighted_score / total_weight
    credit_rating = determine_credit_rating(credit_score)

    calculation_details.update({
        "scores": scores,
        "credit_score": credit_score,
        "credit_rating": credit_rating,
    })
    
    return calculation_details

# %%
p = calculate_credit_rating(metrics, nested_dict)

# %%
def get_expected_metrics(data, n=100):
    return {
        category: {metric: sum(values[-n:]) / min(len(values), n) 
                   for metric, values in metrics.items()}
        for category, metrics in data.items()
    }


def get_nested_dict(data):
    nested_dict = {}

    for (category, metric), values in data.iterrows():
        if category not in nested_dict:
            nested_dict[category] = {}
        nested_dict[category][metric] = values.tolist()

    return nested_dict


def get_nested_dict(file_path):
    
    data = pd.read_excel(file_path, index_col=[0, 1])
    nested_dict = {}

    for (category, metric), values in data.iterrows():
        if category not in nested_dict:
            nested_dict[category] = {}
        nested_dict[category][metric] = values.tolist()

    return nested_dict


def get_period_metrics(data):
    n = len(data['leverage_coverage_metrics']['debt_to_equity'])
    return {
        i: {
            category: {metric: values[i] 
            for metric, values in metrics.items()}
            for category, metrics in data.items()
        }
        for i in range(n)
    }

def bayesian_ridge_transform(data):
    list_length = len(next(iter(next(iter(data.values())).values())))
    return [
        {
            category: {
                metric: values[i] for metric, values in metrics.items()
            } for category, metrics in data.items()
        } for i in range(list_length)
    ]


def bayesian_ridge_model(metrics, periods=1, look_back_periods=5, max_iter=300, tol=1e-3):
    import numpy as np
    from sklearn.linear_model import BayesianRidge

    predictions = {}
    
    for metric_group, values_dict in metrics.items():
        predictions[metric_group] = {}
        for metric, values in values_dict.items():
            X = np.arange(len(values)).reshape(-1, 1)
            
            model = BayesianRidge(max_iter=max_iter, tol=tol).fit(X, values)
            
            next_periods = np.arange(len(values), len(values) + periods).reshape(-1, 1)
            predictions[metric_group][metric] = model.predict(next_periods).tolist() if periods > 0 else list(values)
    return predictions



def bayesian_ridge_model(metrics, periods=1, look_back_periods=5, max_iter=300, tol=1e-3):
    import numpy as np
    from sklearn.linear_model import BayesianRidge
    predictions = {}
    periods, look_back_periods = abs(periods), abs(look_back_periods)
    
    for metric_group, values_dict in metrics.items():
        predictions[metric_group] = {}
        for metric, values in values_dict.items():
            
            recent_values = values[-look_back_periods:]
            X = np.arange(len(recent_values)).reshape(-1, 1)
            
            model = BayesianRidge(max_iter=max_iter, tol=tol).fit(X, recent_values)
            
            next_periods = np.arange(look_back_periods, look_back_periods + periods).reshape(-1, 1)
            predictions[metric_group][metric] = model.predict(next_periods).tolist() if periods > 0 else list(recent_values)
    return predictions

# %%
rating_description_dict = {
    "Aaa": "Issuers assessed Aaa are judged to have the highest intrinsic, or standalone, financial strength, and thus subject to the lowest level of credit risk absent any possibility of extraordinary support from an affiliate or a government.",
    "Aa": "Issuers assessed Aa are judged to have high intrinsic, or standalone, financial strength, and thus subject to very low credit risk absent any possibility of extraordinary support from an affiliate or a government.",
    "A": "Issuers assessed A are judged to have upper-medium-grade intrinsic, or standalone, financial strength, and thus subject to low credit risk absent any possibility of extraordinary support from an affiliate or a government.",
    "Baa": "Issuers assessed Baa are judged to have medium-grade intrinsic, or standalone, financial strength, and thus subject to moderate credit risk and, as such, may possess certain speculative credit elements absent any possibility of extraordinary support from an affiliate or a government.",
    "Ba": "Issuers assessed Ba are judged to have speculative intrinsic, or standalone, financial strength, and are subject to substantial credit risk absent any possibility of extraordinary support from an affiliate or a government.",
    "B": "Issuers assessed B are judged to have speculative intrinsic, or standalone, financial strength, and are subject to high credit risk absent any possibility of extraordinary support from an affiliate or a government.",
    "Caa": "Issuers assessed Caa are judged to have speculative intrinsic, or standalone, financial strength, and are subject to very high credit risk absent any possibility of extraordinary support from an affiliate or a government.",
    "Ca": "Issuers assessed Ca have highly speculative intrinsic, or standalone, financial strength, and are likely to be either in, or very near, default, with some prospect for recovery of principal and interest; or, these issuers have avoided default or are expected to avoid default through the provision of extraordinary support from an affiliate or a government.",
    "C": "Issuers assessed C are typically in default, with little prospect for recovery of principal or interest; or, these issuers are benefiting from a government or affiliate support but are likely to be liquidated over time; without support there would be little prospect for recovery of principal or interest."
}

# %%
rating_meta = {
    "Score Range": ["≤ 2.5", "≤ 3.5", "≤ 4.5", "≤ 5.5", "≤ 6.5", "≤ 7.5", "≤ 8.5", "≤ 9.5", "> 9.5"],
    "Rating": ["Aaa", "Aa", "A", "Baa", "Ba", "B", "Caa", "Ca", "C"],
    "Description": [
        "Issuers assessed Aaa are judged to have the highest intrinsic, or standalone, financial strength, and thus subject to the lowest level of credit risk absent any possibility of extraordinary support from an affiliate or a government.",
        "Issuers assessed Aa are judged to have high intrinsic, or standalone, financial strength, and thus subject to very low credit risk absent any possibility of extraordinary support from an affiliate or a government.",
        "Issuers assessed A are judged to have upper-medium-grade intrinsic, or standalone, financial strength, and thus subject to low credit risk absent any possibility of extraordinary support from an affiliate or a government.",
        "Issuers assessed Baa are judged to have medium-grade intrinsic, or standalone, financial strength, and thus subject to moderate credit risk and, as such, may possess certain speculative credit elements absent any possibility of extraordinary support from an affiliate or a government.",
        "Issuers assessed Ba are judged to have speculative intrinsic, or standalone, financial strength, and are subject to substantial credit risk absent any possibility of extraordinary support from an affiliate or a government.",
        "Issuers assessed B are judged to have speculative intrinsic, or standalone, financial strength, and are subject to high credit risk absent any possibility of extraordinary support from an affiliate or a government.",
        "Issuers assessed Caa are judged to have speculative intrinsic, or standalone, financial strength, and are subject to very high credit risk absent any possibility of extraordinary support from an affiliate or a government.",
        "Issuers assessed Ca have highly speculative intrinsic, or standalone, financial strength, and are likely to be either in, or very near, default, with some prospect for recovery of principal and interest; or, these issuers have avoided default or are expected to avoid default through the provision of extraordinary support from an affiliate or a government.",
        "Issuers assessed C are typically in default, with little prospect for recovery of principal or interest; or, these issuers are benefiting from a government or affiliate support but are likely to be liquidated over time; without support there would be little prospect for recovery of principal or interest."
    ],
    "Probability of Default": ["0.00%", "0.01%", "0.10%", "0.46%", "2.31%", "7.62%", "17.86%", "50.00%", "100.00%"]
}

# %%
def get_rating_meta(rating):

    index = rating_meta["Rating"].index(rating)
    result = {}
    for key, value in rating_meta.items():
        formatted_key = key.lower().replace(' ', '_')
        
        if key == "Probability of Default":
            result[formatted_key] = float(value[index].rstrip('%'))
        elif key == "Score Range":
            score_str = value[index].replace('≤', '').replace('>', '').strip()
            result[formatted_key] = float(score_str)
        else:
            result[formatted_key] = value[index]

    return result

# Example usage
target_rating = "C"  # Using "C" to test the '> 9.5' case
result = get_rating_meta(target_rating)
print(result)
# Out:
# {'score_range': 9.5, 'rating': 'C', 'description': 'Issuers assessed C are typically in default, with little prospect for recovery of principal or interest; or, these issuers are benefiting from a government or affiliate support but are likely to be liquidated over time; without support there would be little prospect for recovery of principal or interest.', 'probability_of_default': 100.0}

# %%
def load_config(company_sector, company_size):
    sector = company_sector.lower()
    file_path = "metrics.json" if sector == "large" else "metrics.json"
    
    with open(file_path, "r") as f:
        return json.load(f)

# %%
company_name = "Banana Capital Ltd"
company_sector = "Corporates"
company_size = "Small"
excel_file_path = "creditwatch_small_medium_company_template.xlsx"
work_directory = r"C:\Users\103763\Projects\HELLO_CREDIT\temp\9397831824fe4796_20240727"

configuration = load_config(company_sector, company_size)
input_dict = {
    "work_directory": work_directory,
    "file_path": excel_file_path,
    "company_meta": {
        "company_name": company_name,
        "company_size": company_size,
        "company_sector": company_sector,
    },
    "probabilistic_model": {
        "periods": 2, 
        "look_back_periods": 5, 
        "max_iter": 300, 
        "tol": 1e-3
    },
    "configuration": configuration
}

# %%
factor_weights = {
    weight: input_dict["configuration"].get(weight)["class_weight"] 
    for weight in input_dict["configuration"]
}

# %%
from functools import partial
from dataclasses import field

@dataclass
class HelloCredit:
    input_dict: dict = field(default_factory=dict)
    
    def __post_init__(self):
        self.nested_dict = get_nested_dict(self.input_dict["file_path"])
        self.company_period_metrics = get_period_metrics(self.nested_dict)
        self.company_expected_metrics = get_expected_metrics(self.nested_dict)
        self.compute_rating = partial(calculate_credit_rating, metrics=self.input_dict["configuration"])
        self.work_dir = self.input_dict["work_directory"]
            
    def update_input_dict(self, input_dict: dict) -> dict:  
        def deep_update(d, u):
            for k, v in u.items():
                if isinstance(v, dict):
                    d[k] = deep_update(d.get(k, {}), v)
                else:
                    d[k] = v
            return d

        self.input_dict = deep_update(self.input_dict, input_dict)
    
    
    def run_function(self) -> None:
        # Expected and Single Period Calcs
        calculator_output = self.compute_rating(ratios=self.company_expected_metrics)
        rating_meta = get_rating_meta(calculator_output["credit_rating"])
        
        calculator_periods_output = {
            period: self.compute_rating(ratios=self.company_period_metrics[period])
            for period in self.company_period_metrics
        }
             
        # Bayesian Model
        model_output = bayesian_ridge_model(self.nested_dict, **self.input_dict["probabilistic_model"])
        model_output_transform = bayesian_ridge_transform(model_output)
        model_output_computed_rating = {
            period: self.compute_rating(ratios=model_output_transform[period]) 
            for period, metrics in enumerate(model_output_transform)
        }
        
        bayesian_model_output = {
            "model_output": model_output,
            "model_output_transform": model_output_transform,
            "computed_rating": model_output_computed_rating,
        }
        
        self.output_dict = {
            "rating_meta": rating_meta,
            "company_expected_metrics": self.company_expected_metrics,
            "company_period_metrics": self.company_period_metrics,
            "calculator_output": calculator_output,
            "calculator_periods_output": calculator_periods_output,
            "bayesian_model_output": bayesian_model_output,
        }
        
        
        files_to_dump = {
            "output_dict.json": self.output_dict,
            "input_dict.json": self.input_dict
        }

        for filename, data in files_to_dump.items():
            file_path = os.path.join(self.work_dir, filename)
            with open(file_path, "w") as f:
                json.dump(data, f)
                
        print("Files Dumped")

# %%
m = HelloCredit(input_dict)

# %%
a = m.run_function()

# %%
for x in a['calculator_periods_output']['computed_rating']:
    print(a['calculator_periods_output']['computed_rating'][x]['credit_rating'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[366], line 1
# ----> 1 for x in a['calculator_periods_output']['computed_rating']:
#       2     print(a['calculator_periods_output']['computed_rating'][x]['credit_rating'])
#
# KeyError: 'computed_rating'

# %%
a['calculator_periods_output']
# Out:
# {0: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 9.9667,
#     'score': 8,
#     'weight': 0.4,
#     'weighted_score': 3.2,
#     'rating': 'Caa'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 13540.42375,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 66.6038,
#     'score': 1,
#     'weight': 0.3,
#     'weighted_score': 0.3,
#     'rating': 'Aaa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.694277,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 3.3666,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 3.8652,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 0.7093,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 1.1335,
#     'score': 7,
#     'weight': 0.5,
#     'weighted_score': 3.5,
#     'rating': 'B'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 16.1309,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 14.6341,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.2,
#    'leverage_coverage_metrics': 4.4,
#    'efficiency_metrics': 6.3999999999999995},
#   'credit_score': 5.5,
#   'credit_rating': 'Baa'},
#  1: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 9.8373,
#     'score': 8,
#     'weight': 0.4,
#     'weighted_score': 3.2,
#     'rating': 'Caa'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 14845.76275,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 18.0796,
#     'score': 5,
#     'weight': 0.3,
#     'weighted_score': 1.5,
#     'rating': 'Baa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.5414800000000001,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 2.9485,
#     'score': 4,
#     'weight': 0.4,
#     'weighted_score': 1.6,
#     'rating': 'A'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 4.8199,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 0.5483,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 1.0048,
#     'score': 7,
#     'weight': 0.5,
#     'weighted_score': 3.5,
#     'rating': 'B'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 14.1651,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 17.0031,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 7.4,
#    'leverage_coverage_metrics': 3.8000000000000003,
#    'efficiency_metrics': 6.3999999999999995},
#   'credit_score': 5.65,
#   'credit_rating': 'Ba'},
#  2: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 11.1502,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 14729.246,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 51.3073,
#     'score': 1,
#     'weight': 0.3,
#     'weighted_score': 0.3,
#     'rating': 'Aaa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.513237,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 2.4745,
#     'score': 4,
#     'weight': 0.4,
#     'weighted_score': 1.6,
#     'rating': 'A'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 7.0297,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 0.5706,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 1.1382,
#     'score': 7,
#     'weight': 0.5,
#     'weighted_score': 3.5,
#     'rating': 'B'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 13.5138,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 10.3288,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 5.8,
#    'leverage_coverage_metrics': 3.6,
#    'efficiency_metrics': 6.3999999999999995},
#   'credit_score': 5.033333333333333,
#   'credit_rating': 'Baa'},
#  3: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 12.8122,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 19313.712249999997,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 21.207,
#     'score': 4,
#     'weight': 0.3,
#     'weighted_score': 1.2,
#     'rating': 'A'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.582016,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 2.2575,
#     'score': 4,
#     'weight': 0.4,
#     'weighted_score': 1.6,
#     'rating': 'A'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 6.4572,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 0.6252,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 1.098,
#     'score': 7,
#     'weight': 0.5,
#     'weighted_score': 3.5,
#     'rating': 'B'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 8.9837,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 19.5497,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.7,
#    'leverage_coverage_metrics': 3.8,
#    'efficiency_metrics': 6.3999999999999995},
#   'credit_score': 5.416666666666667,
#   'credit_rating': 'Baa'},
#  4: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 16.455,
#     'score': 6,
#     'weight': 0.4,
#     'weighted_score': 2.4000000000000004,
#     'rating': 'Ba'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 31301.931500000002,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 6.2676,
#     'score': 7,
#     'weight': 0.3,
#     'weighted_score': 2.1,
#     'rating': 'B'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.51855,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 1.9345,
#     'score': 3,
#     'weight': 0.4,
#     'weighted_score': 1.2000000000000002,
#     'rating': 'Aa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 6.4745,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 0.5656,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.9175,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 12.7554,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 26.9635,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 7.199999999999999,
#    'leverage_coverage_metrics': 3.2000000000000006,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 5.458333333333333,
#   'credit_rating': 'Baa'},
#  5: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 12.4319,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 53258.1245,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 79.3207,
#     'score': 1,
#     'weight': 0.3,
#     'weighted_score': 0.3,
#     'rating': 'Aaa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.17954699999999998,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 0.74,
#     'score': 2,
#     'weight': 0.4,
#     'weighted_score': 0.8,
#     'rating': 'Aaa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 5.7828,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 0.4165,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.9943,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 15.4957,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 17.9734,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 5.8,
#    'leverage_coverage_metrics': 2.6,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 4.741666666666666,
#   'credit_rating': 'Baa'},
#  6: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 10.1649,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 61048.28799999999,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 59.0831,
#     'score': 1,
#     'weight': 0.3,
#     'weighted_score': 0.3,
#     'rating': 'Aaa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.851673,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 3.5469,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 4.5832,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 3.4809,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 1.0671,
#     'score': 7,
#     'weight': 0.5,
#     'weighted_score': 3.5,
#     'rating': 'B'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 10.5054,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 14.6078,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 5.8,
#    'leverage_coverage_metrics': 5.6,
#    'efficiency_metrics': 6.3999999999999995},
#   'credit_score': 5.866666666666666,
#   'credit_rating': 'Ba'},
#  7: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 11.051,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 68735.772,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 13.4937,
#     'score': 6,
#     'weight': 0.3,
#     'weighted_score': 1.7999999999999998,
#     'rating': 'Ba'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.654936,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 3.0054,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 3.6629,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 1.8991,
#     'score': 8,
#     'weight': 0.2,
#     'weighted_score': 1.6,
#     'rating': 'Caa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.9852,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 10.0835,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 9.766,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 7.3,
#    'leverage_coverage_metrics': 5.2,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 6.325,
#   'credit_rating': 'Ba'},
#  8: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 12.2764,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 80945.28925,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 31.6032,
#     'score': 2,
#     'weight': 0.3,
#     'weighted_score': 0.6,
#     'rating': 'Aaa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.6750069999999999,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 3.0252,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 3.7094,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -36.8776,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.9539,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 12.3275,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 8.3038,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.1,
#    'leverage_coverage_metrics': 3.8000000000000003,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 5.341666666666667,
#   'credit_rating': 'Baa'},
#  9: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 11.5218,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 88057.04075,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 12.9271,
#     'score': 6,
#     'weight': 0.3,
#     'weighted_score': 1.7999999999999998,
#     'rating': 'Ba'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.705304,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 2.9993,
#     'score': 4,
#     'weight': 0.4,
#     'weighted_score': 1.6,
#     'rating': 'A'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 3.0118,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 8.1915,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.9111,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 9.3515,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 8.6476,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 7.3,
#    'leverage_coverage_metrics': 5.0,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 6.241666666666666,
#   'credit_rating': 'Ba'},
#  10: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 15.2427,
#     'score': 6,
#     'weight': 0.4,
#     'weighted_score': 2.4000000000000004,
#     'rating': 'Ba'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 106659.644,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': -30.1893,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.6780240000000001,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 3.3896,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 3.0072,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 3.2486,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.6345,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 12.7281,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 8.7774,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 7.5,
#    'leverage_coverage_metrics': 5.4,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 6.475,
#   'credit_rating': 'Ba'},
#  11: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 14.6678,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 180046.22999999998,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 21.1985,
#     'score': 4,
#     'weight': 0.3,
#     'weighted_score': 1.2,
#     'rating': 'A'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.7469750000000001,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 4.8311,
#     'score': 6,
#     'weight': 0.4,
#     'weighted_score': 2.4000000000000004,
#     'rating': 'Ba'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 3.0307,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -13.984,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.5445,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 20.4763,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 6.2426,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.4,
#    'leverage_coverage_metrics': 4.2,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 5.608333333333333,
#   'credit_rating': 'Ba'},
#  12: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 12.1895,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 224801.91825,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 86.2059,
#     'score': 1,
#     'weight': 0.3,
#     'weighted_score': 0.3,
#     'rating': 'Aaa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.7660009999999999,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 4.2058,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 3.9186,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -6.72,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.685,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 18.0066,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 6.0205,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 5.5,
#    'leverage_coverage_metrics': 4.0,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 5.225,
#   'credit_rating': 'Baa'},
#  13: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 11.5022,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 223559.65625,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 22.2041,
#     'score': 4,
#     'weight': 0.3,
#     'weighted_score': 1.2,
#     'rating': 'A'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.7985859999999999,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 4.7332,
#     'score': 6,
#     'weight': 0.4,
#     'weighted_score': 2.4000000000000004,
#     'rating': 'Ba'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 4.3901,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -13.9618,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.6571,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 16.7933,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 5.6049,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.4,
#    'leverage_coverage_metrics': 4.4,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 5.691666666666666,
#   'credit_rating': 'Ba'},
#  14: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 14.2156,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 243352.75999999998,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 19.835,
#     'score': 5,
#     'weight': 0.3,
#     'weighted_score': 1.5,
#     'rating': 'Baa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.733993,
#     'score': 3,
#     'weight': 0.2,
#     'weighted_score': 0.6000000000000001,
#     'rating': 'Aa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 3.8616,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 5.2548,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 3.8491,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.639,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 15.7246,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 8.0768,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.7,
#    'leverage_coverage_metrics': 5.4,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 6.208333333333333,
#   'credit_rating': 'Ba'},
#  15: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 14.8605,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 404407.5,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 17.6158,
#     'score': 5,
#     'weight': 0.3,
#     'weighted_score': 1.5,
#     'rating': 'Baa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 0.351504,
#     'score': 2,
#     'weight': 0.2,
#     'weighted_score': 0.4,
#     'rating': 'Aaa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 3.2351,
#     'score': 5,
#     'weight': 0.4,
#     'weighted_score': 2.0,
#     'rating': 'Baa'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 6.1303,
#     'score': 4,
#     'weight': 0.2,
#     'weighted_score': 0.8,
#     'rating': 'A'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': 1.5973,
#     'score': 8,
#     'weight': 0.2,
#     'weighted_score': 1.6,
#     'rating': 'Caa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.5305,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 19.8106,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 12.0905,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.7,
#    'leverage_coverage_metrics': 4.800000000000001,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 5.958333333333333,
#   'credit_rating': 'Ba'},
#  16: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 3.9244,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 367920.0,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 64.2901,
#     'score': 1,
#     'weight': 0.3,
#     'weighted_score': 0.3,
#     'rating': 'Aaa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 1.346962,
#     'score': 5,
#     'weight': 0.2,
#     'weighted_score': 1.0,
#     'rating': 'Baa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 12.9589,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 1.8618,
#     'score': 6,
#     'weight': 0.2,
#     'weighted_score': 1.2000000000000002,
#     'rating': 'Ba'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -1.5709,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.731,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 16.0818,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 3.2677,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 6.3,
#    'leverage_coverage_metrics': 6.0,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 6.325,
#   'credit_rating': 'Ba'},
#  17: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 1.1446,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 306337.5,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': -22.548,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 4.570813,
#     'score': 8,
#     'weight': 0.2,
#     'weighted_score': 1.6,
#     'rating': 'Caa'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 66.8042,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 0.4145,
#     'score': 7,
#     'weight': 0.2,
#     'weighted_score': 1.4000000000000001,
#     'rating': 'B'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -1.5101,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.6485,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 20.4595,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 4.1302,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 8.7,
#    'leverage_coverage_metrics': 6.800000000000001,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 7.458333333333333,
#   'credit_rating': 'B'},
#  18: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 5.4919,
#     'score': 8,
#     'weight': 0.4,
#     'weighted_score': 3.2,
#     'rating': 'Caa'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 286475.0,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': -8.4687,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 16.209048,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 16.5446,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 1.5622,
#     'score': 6,
#     'weight': 0.2,
#     'weighted_score': 1.2000000000000002,
#     'rating': 'Ba'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -1.5208,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.6751,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 18.8456,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 7.7886,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 8.299999999999999,
#    'leverage_coverage_metrics': 6.800000000000001,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 7.325,
#   'credit_rating': 'B'},
#  19: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 6.147,
#     'score': 8,
#     'weight': 0.4,
#     'weighted_score': 3.2,
#     'rating': 'Caa'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 255517.5,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': -29.4359,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 5.61958175,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 22.9234,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 0.4593,
#     'score': 7,
#     'weight': 0.2,
#     'weighted_score': 1.4000000000000001,
#     'rating': 'B'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -1.363,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.5211,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 26.3973,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 12.2937,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 8.299999999999999,
#    'leverage_coverage_metrics': 7.000000000000001,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 7.408333333333333,
#   'credit_rating': 'B'},
#  20: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': -2.7852,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 229267.5,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': -2.1068,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 5.61958175,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 25.824099999999998,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': -0.1847,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -1.3286,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.5703,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 15.8248,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 15.1362,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 8.7,
#    'leverage_coverage_metrics': 7.4,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 7.708333333333333,
#   'credit_rating': 'Caa'},
#  21: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 5.6347,
#     'score': 8,
#     'weight': 0.4,
#     'weighted_score': 3.2,
#     'rating': 'Caa'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 263182.5,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 16.3818,
#     'score': 5,
#     'weight': 0.3,
#     'weighted_score': 1.5,
#     'rating': 'Baa'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 5.61958175,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 25.944,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 0.4896,
#     'score': 7,
#     'weight': 0.2,
#     'weighted_score': 1.4000000000000001,
#     'rating': 'B'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -1.2899,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.6534,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 15.936,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 20.9522,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 7.1,
#    'leverage_coverage_metrics': 7.000000000000001,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 7.008333333333334,
#   'credit_rating': 'B'},
#  22: {'metrics': {'ebitda_margin': {'category': 'profitability_metrics',
#     'value': 13.4327,
#     'score': 7,
#     'weight': 0.4,
#     'weighted_score': 2.8000000000000003,
#     'rating': 'B'},
#    'total_assets': {'category': 'profitability_metrics',
#     'value': 232557.5,
#     'score': 8,
#     'weight': 0.3,
#     'weighted_score': 2.4,
#     'rating': 'Caa'},
#    'sales_growth': {'category': 'profitability_metrics',
#     'value': 12.4007,
#     'score': 6,
#     'weight': 0.3,
#     'weighted_score': 1.7999999999999998,
#     'rating': 'Ba'},
#    'debt_to_equity': {'category': 'leverage_coverage_metrics',
#     'value': 5.61958175,
#     'score': 9,
#     'weight': 0.2,
#     'weighted_score': 1.8,
#     'rating': 'Ca'},
#    'debt_to_ebitda': {'category': 'leverage_coverage_metrics',
#     'value': 9.7695,
#     'score': 9,
#     'weight': 0.4,
#     'weighted_score': 3.6,
#     'rating': 'Ca'},
#    'ebitda_to_interest_expense': {'category': 'leverage_coverage_metrics',
#     'value': 1.1713,
#     'score': 6,
#     'weight': 0.2,
#     'weighted_score': 1.2000000000000002,
#     'rating': 'Ba'},
#    'debt_to_tangible_assets': {'category': 'leverage_coverage_metrics',
#     'value': -1.2007,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'},
#    'asset_turnover': {'category': 'efficiency_metrics',
#     'value': 0.7295,
#     'score': 8,
#     'weight': 0.5,
#     'weighted_score': 4.0,
#     'rating': 'Caa'},
#    'inventory_to_cost_of_sales': {'category': 'efficiency_metrics',
#     'value': 20.1974,
#     'score': 9,
#     'weight': 0.3,
#     'weighted_score': 2.6999999999999997,
#     'rating': 'Ca'},
#    'cash_to_assets': {'category': 'efficiency_metrics',
#     'value': 8.5559,
#     'score': 1,
#     'weight': 0.2,
#     'weighted_score': 0.2,
#     'rating': 'Aaa'}},
#   'scores': {'profitability_metrics': 7.0,
#    'leverage_coverage_metrics': 6.800000000000001,
#    'efficiency_metrics': 6.8999999999999995},
#   'credit_score': 6.891666666666667,
#   'credit_rating': 'B'}}

# %%
from datetime import datetime

# %%
import hashlib
import os

def get_file_id(filepath):
    filename = os.path.splitext(os.path.basename(filepath))[0]
    timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
    
    with open(filepath, 'rb') as f:
        file_content = f.read()
        
    hash_value = hashlib.sha256(file_content).hexdigest()[:16]
    return f"{hash_value}_{timestamp}" #f"{filename}_{hash_value}"

# Example usage
file_path = 'creditwatch_small_medium_company_template.xlsx'
unique_id = get_file_id(file_path)
print(unique_id)
# Out:
# 9397831824fe4796_20240727221712

# %%
print(unique_id)
# Out:
# 9397831824fe4796_20240727221712

# %%
from dataclasses import field



@dataclass
class HelloCredit:
    file_path: str
    company_meta: dict = field(default_factory=dict)
    
    
    def __post_init__(self):        
        self.file_path = self.file_path or "data.xlsx"
        
        
        
        self.metrics_path = self.metrics_path or "metrics.json"
        
        with open(self.metrics_path, "r") as f:
            self.metrics = json.load(f)
            
        self.class_weights = {m: self.metrics[m]["class_weight"] for m in self.metrics}
        self.dataframe = pd.read_excel(self.file_path, index_col=[0, 1])
        self.nested_dict = get_nested_dict(self.dataframe)
        self.company_period_metrics = get_period_metrics(self.nested_dict)
        self.company_expected_metrics = get_expected_metrics(self.nested_dict)
        
        self.input_dict = {
            "company_name": self.company_meta["company_name"],
            "calculator_model": {
                "sector": self.company_meta["company_sector"], 
                "size": self.company_meta["company_size"]
            },
            "factor_weights_model": self.class_weights,
            "probabilistic_model": {"periods": 1, "look_back_periods": 5, "max_iter": 300, "tol": 1e-3}
        }

    
    def update_input_dict(self, input_dict: dict) -> dict:  
        def deep_update(d, u):
            for k, v in u.items():
                if isinstance(v, dict):
                    d[k] = deep_update(d.get(k, {}), v)
                else:
                    d[k] = v
            return d

        self.input_dict = deep_update(self.input_dict, input_dict)
    
    
    def update_output_dict(self):
        calculator_output = calculate_credit_rating(self.metrics, self.company_expected_metrics)

        # Single Period Calcs
        calculator_periods_output = {}
        for period in self.company_period_metrics:
            calculator_periods_output[period] = calculate_credit_rating(self.metrics, self.company_period_metrics[period])
             
        # Bayesian Model
        bayesian_model_output = {}
        model_output = bayesian_ridge_model(self.nested_dict, **self.input_dict["probabilistic_model"])
        out_of_sample = bayesian_ridge_transform(model_output)
        for period, metrics in enumerate(out_of_sample):
            bayesian_model_output[period] = calculate_credit_rating(self.metrics, out_of_sample[period])
            

        # Rating Description
        rating_description = rating_description_dict[calculator_output["credit_rating"]]

        output_dict = {
            "company_name": self.input_dict["company_name"],
            "rating_description": rating_description,
            "company_expected_metrics": self.company_expected_metrics,
            "company_period_metrics": self.company_period_metrics,
            "calculator_output": calculator_output,
            "calculator_periods_output": calculator_periods_output,
            "bayesian_model_output": bayesian_model_output,
            "metrics": self.metrics
        }
        return output_dict

# %%
@dataclass
class HelloCredit:
    file_path: str = None
    metrics_path: str = None
    
    def __post_init__(self):        
        self.file_path = self.file_path or "data.xlsx"
        self.metrics_path = self.metrics_path or "metrics.json"
        
        with open(self.metrics_path, "r") as f:
            self.metrics = json.load(f)
            
        self.class_weights = {m: self.metrics[m]["class_weight"] for m in self.metrics}
        self.dataframe = pd.read_excel(self.file_path, index_col=[0, 1])
        self.nested_dict = get_nested_dict(self.dataframe)
        self.company_period_metrics = get_period_metrics(self.nested_dict)
        self.company_expected_metrics = get_expected_metrics(self.nested_dict)
        self.input_dict = {
            "company_name": None,
            "calculator_model": {"sector": "Corporates", "size": "Small"},
            "factor_weights_model": self.class_weights,
            "probabilistic_model": {"periods": 1, "max_iter": 300, "tol": 1e-3}
        }

    
    def update_input_dict(self, input_dict: dict) -> dict:  
        def deep_update(d, u):
            for k, v in u.items():
                if isinstance(v, dict):
                    d[k] = deep_update(d.get(k, {}), v)
                else:
                    d[k] = v
            return d

        self.input_dict = deep_update(self.input_dict, input_dict)
    
    
    def update_output_dict(self):
        calculator = CreditRatingCalculator(self.metrics)
        calculator.calculate_credit_rating(self.company_expected_metrics)
        calculator_output = calculator.calculation_details

        # Single Period Calcs
        calculator_periods_output = {}
        for period in self.company_period_metrics:
            calculator = CreditRatingCalculator(self.metrics)
            calculator.calculate_credit_rating(self.company_period_metrics[period])
            calculator_periods_output[period] = calculator.calculation_details

        # Bayesian Model
        bayesian_model_output = {}
        
        model_output = bayesian_ridge_model(self.nested_dict, **self.input_dict["probabilistic_model"])
        out_of_sample = bayesian_ridge_transform(model_output)
        for period, metrics in enumerate(out_of_sample):
            calculator = CreditRatingCalculator(self.metrics)
            calculator.calculate_credit_rating(out_of_sample[period])
            bayesian_model_output[period] = calculator.calculation_details

        # Rating Description
        rating_description = rating_description_dict[calculator_output["credit_rating"]]

        output_dict = {
            "company_name": self.input_dict["company_name"],
            "rating_description": rating_description,
            "company_expected_metrics": self.company_expected_metrics,
            "company_period_metrics": self.company_period_metrics,
            "calculator_output": calculator_output,
            "calculator_periods_output": calculator_periods_output,
            "bayesian_model_output": bayesian_model_output,
            "metrics": self.metrics
        }
        return output_dict

# %%
m = HelloCredit("stienhoff_data - Copy - Copy.xlsx")

# %%
output = m.update_output_dict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 output = m.update_output_dict()
#
# Cell In[24], line 39, in HelloCredit.update_output_dict(self)
#      38 def update_output_dict(self):
# ---> 39     calculator = CreditRatingCalculator(self.metrics)
#      40     calculator.calculate_credit_rating(self.company_expected_metrics)
#      41     calculator_output = calculator.calculation_details
#
# NameError: name 'CreditRatingCalculator' is not defined

# %%
with open("outputt.json", "w") as f:
    json.dump(output, f)

# %% [markdown]
# # MODEL TRAINING

# %%
def calculate_loss(model_inputs):
    yhat = []
    for company in features.index:
        ratios = features.loc[company][model_metrics].to_dict()    
        model = CreditRatingCalculator(model_inputs)
        model.calculate_credit_rating(ratios)

        credit_score = model.credit_score
        credit_rating = model.credit_rating

        yhat.append(credit_score)

    y_true = targets['numeric_rating']
    yhat = np.round(yhat, 1)
    loss = mean_absolute_percentage_error(yhat, y_true)
    return loss

def normalize_weights(weights):
    total = sum(weights)
    return [weight / total for weight in weights]

def train_model(model_inputs, learning_rate=0.01, num_iterations=1000):
    
    np.random.seed(23)
    
    # Initialize weights and class_weights
    for category in model_inputs.values():
        category["class_weight"] = np.random.random()
        category["weights"] = np.random.random(len(category["weights"]))
        category["weights"] = normalize_weights(category["weights"])

    # Perform gradient descent
    for epoch in range(num_iterations):
        # Calculate gradients
        gradients = {}
        for category, category_data in model_inputs.items():
            gradients[category] = {
                "class_weight": 0.0,
                "weights": np.zeros_like(category_data["weights"])
            }

        # Calculate loss and gradients
        loss = calculate_loss(model_inputs)
        for category, category_data in model_inputs.items():
            # Calculate gradient for class_weight
            category_data["class_weight"] += 0.0001
            gradients[category]["class_weight"] = (calculate_loss(model_inputs) - loss) / 0.0001
            category_data["class_weight"] -= 0.0001

            # Calculate gradients for weights
            for i in range(len(category_data["weights"])):
                category_data["weights"][i] += 0.0001
                gradients[category]["weights"][i] = (calculate_loss(model_inputs) - loss) / 0.0001
                category_data["weights"][i] -= 0.0001

        # Update weights and class_weights
        for category, category_data in model_inputs.items():
            category_data["class_weight"] -= learning_rate * gradients[category]["class_weight"]
            category_data["weights"] -= learning_rate * gradients[category]["weights"]
            category_data["weights"] = normalize_weights(category_data["weights"])

        # Normalize class_weights
        class_weights = [category_data["class_weight"] for category_data in model_inputs.values()]
        normalized_class_weights = normalize_weights(class_weights)
        for category, weight in zip(model_inputs.keys(), normalized_class_weights):
            model_inputs[category]["class_weight"] = weight
        
        if epoch % 100 == 0:
            print(f"Epoch {epoch}: Loss = {loss:.4f}")
        
    return model_inputs

# %%
# Train the model
trained_model_inputs = train_model(model_inputs, learning_rate=0.1, num_iterations=300)

# Print the optimized weights and class_weights
for category, category_data in trained_model_inputs.items():
    print(f"Category: {category}")
    print(f"Class Weight: {category_data['class_weight']}")
    print(f"Weights: {category_data['weights']}")
    print()
# Out:
# Epoch 0: Loss = 0.2761
# Epoch 100: Loss = 0.2593
# Epoch 200: Loss = 0.2593
# Category: profitability
# Class Weight: 0.367213686010887
# Weights: [1.0]
#
# Category: leverage_coverage
# Class Weight: 0.614510015986914
# Weights: [0.2373745964555163, 0.18580497915793837, 0.5768204243865455]
#
# Category: efficiency
# Class Weight: 0.018276298002199015
# Weights: [0.3883666310182689, 0.6116333689817312]

# %%
import numpy as np
from scipy.optimize import minimize

def calculate_loss(model_inputs):
    yhat = []
    for company in features.index:
        ratios = features.loc[company][model_metrics].to_dict()
        model = CreditRatingCalculator(model_inputs)
        model.calculate_credit_rating(ratios)
        credit_score = model.credit_score
        yhat.append(credit_score)
    y_true = targets['numeric_rating']
    yhat = np.round(yhat, 1)
    loss = mean_absolute_percentage_error(yhat, y_true)
    return loss

def normalize_weights(weights):
    total = sum(weights)
    return [weight / total for weight in weights]

def train_model(model_inputs, learning_rate=0.01, num_iterations=5000):
    np.random.seed(23)
    
    # Initialize weights and class_weights
    for category in model_inputs.values():
        category["class_weight"] = np.random.random()
        category["weights"] = np.random.random(len(category["weights"]))
        category["weights"] = normalize_weights(category["weights"])
    
    # Define the objective function for optimization
    def objective(params):
        idx = 0
        for category in model_inputs.values():
            category["class_weight"] = params[idx]
            idx += 1
            category["weights"] = params[idx:idx+len(category["weights"])]
            idx += len(category["weights"])
        return calculate_loss(model_inputs)
    
    # Define the bounds for optimization
    bounds = []
    for category in model_inputs.values():
        bounds.append((0, 1))  # Class weight bounds
        bounds.extend([(0, 1)] * len(category["weights"]))  # Weight bounds
    
    # Perform optimization using L-BFGS-B
    initial_params = []
    for category in model_inputs.values():
        initial_params.append(category["class_weight"])
        initial_params.extend(category["weights"])
    
    result = minimize(objective, initial_params, method='L-BFGS-B', bounds=bounds, options={'maxiter': num_iterations})
    print(result)
    
    # Update the optimized weights and class_weights
    optimized_params = result.x
    idx = 0
    for category in model_inputs.values():
        category["class_weight"] = optimized_params[idx]
        idx += 1
        category["weights"] = optimized_params[idx:idx+len(category["weights"])]
        idx += len(category["weights"])
    
    return model_inputs

# %%
# Train the model
trained_model_inputs = train_model(model_inputs, learning_rate=0.01, num_iterations=3000)

# Print the optimized weights and class_weights
for category, category_data in trained_model_inputs.items():
    print(f"Category: {category}")
    print(f"Class Weight: {category_data['class_weight']}")
    print(f"Weights: {category_data['weights']}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Train the model
# ----> 2 trained_model_inputs = train_model(model_inputs, learning_rate=0.01, num_iterations=3000)
#       4 # Print the optimized weights and class_weights
#       5 for category, category_data in trained_model_inputs.items():
#
# NameError: name 'model_inputs' is not defined

# %%
def calculate_loss(model_inputs):
    yhat = []
    for company in features.index:
        ratios = features.loc[company][model_metrics].to_dict()
        model = CreditRatingCalculator(model_inputs)
        model.calculate_credit_rating(ratios)
        credit_score = model.credit_score
        yhat.append(credit_score)
    y_true = targets['numeric_rating']
    yhat = np.round(yhat, 1)
    loss = mean_absolute_percentage_error(yhat, y_true)
    return loss

# %%
calculate_loss(trained_model_inputs)
# Out:
# 0.2592912997321396

# %%
def train_model(model_inputs, learning_rate=0.01, num_iterations=5000):
    np.random.seed(23)
    
    # Initialize weights and class_weights
    for category in model_inputs.values():
        category["class_weight"] = np.random.random()
        category["weights"] = np.random.random(len(category["weights"]))
        category["weights"] = normalize_weights(category["weights"])
    
    # Define the objective function for optimization
    def objective(params):
        idx = 0
        for category in model_inputs.values():
            category["class_weight"] = params[idx]
            idx += 1
            category["weights"] = params[idx:idx+len(category["weights"])]
            idx += len(category["weights"])
        return calculate_loss(model_inputs)
    
    # Define the bounds for optimization
    bounds = []
    for category in model_inputs.values():
        bounds.append((0, 1))  # Class weight bounds
        bounds.extend([(0, 1)] * len(category["weights"]))  # Weight bounds
    
    # Perform optimization using L-BFGS-B
    initial_params = []
    for category in model_inputs.values():
        initial_params.append(category["class_weight"])
        initial_params.extend(category["weights"])
    
    result = minimize(objective, initial_params, method='L-BFGS-B', bounds=bounds, options={'maxiter': num_iterations})
    
    # Update the optimized weights and class_weights
    optimized_params = result.x
    idx = 0
    for category in model_inputs.values():
        category["class_weight"] = optimized_params[idx]
        idx += 1
        category["weights"] = optimized_params[idx:idx+len(category["weights"])]
        idx += len(category["weights"])
    
    # Calculate and print the final error
    final_error = calculate_loss(model_inputs)
    print(f"Final Error: {final_error:.4f}")
    
    return model_inputs

# %%
def calculate_loss(model_inputs):
    yhat = []
    for company in features.index:
        ratios = features.loc[company][model_metrics].to_dict()    
        model = CreditRatingCalculator(model_inputs)
        model.calculate_credit_rating(ratios)

        credit_score = model.credit_score
        credit_rating = model.credit_rating

        yhat.append(credit_score)

    y_true = targets['numeric_rating']
    yhat = np.round(yhat, 1)
    loss = mean_absolute_percentage_error(yhat, y_true)
    print(y_true.values)
    print(yhat)
    return loss

# %%
calculate_loss(trained_model_inputs)
# Out:
# [5.5 5.5 4.5 6.5 4.5 5.5 6.5 4.5 6.5 6.5 7.5 5.5 5.5 6.5 5.5 5.5 6.5 6.5
#  5.5 6.5 5.5 6.5 5.5 6.5 6.5 6.5 6.5 6.5 5.5 8.5 6.5 6.5 6.5 6.5 6.5 6.5
#  6.5 6.5 6.5 6.5 6.5 6.5 6.5 6.5 6.5 6.5 5.5 6.5 5.5 6.5 6.5 6.5 6.5 6.5
#  6.5 6.5 6.5 5.5 6.5 6.5 7.5 6.5 6.5 5.5 5.5 6.5 6.5 5.5 6.5 6.5]
# [9.1 3.7 6.9 9.3 2.6 3.5 9.4 5.8 6.8 0.2 3.5 3.7 4.  0.2 3.5 9.2 0.2 7.
#  0.2 3.8 3.5 0.2 3.6 9.3 9.2 9.2 9.2 3.7 7.  9.3 0.2 5.7 9.  9.  9.4 2.4
#  3.8 3.8 4.6 8.1 8.  9.2 4.6 4.6 9.1 6.9 9.3 4.7 4.  6.9 9.1 3.8 3.7 3.7
#  3.7 0.3 4.6 4.1 9.2 6.9 6.9 9.  6.9 4.7 2.5 4.2 3.7 4.7 4.7 4.2]
# 3.305207936385858

# %%
def get_buckets(min_val, max_val, lower_is_better=False, num_buckets=9):
    """
    Generates optimized buckets based on min, max values, desired number of buckets, and whether lower values are better.

    Args:
        min_val (float): The minimum value.
        max_val (float): The maximum value.
        num_buckets (int, optional): Number of buckets. Defaults to 9.
        lower_is_better (bool, optional): True if lower values are better, else False. Defaults to False.

    Returns:
        list: List of tuples (start, end) representing each bucket's range.
    """
    min_val, max_val = (max_val, min_val) if lower_is_better else (min_val, max_val)
    interval = (max_val - min_val) / (num_buckets - 1)
    buckets = [(round(min_val + i * interval, 2), round(min_val + (i + 1) * interval, 2)) for i in range(num_buckets - 1)]
    buckets.append((round(max_val - interval, 2), max_val))
    return list(reversed(buckets)) if lower_is_better else buckets


# Redefine the values and number of buckets for clarity
min_val = -50
max_val = 50

# Generate the optimized buckets
buckets_list = get_buckets(min_val,  max_val)
print(buckets_list)
# Out:
# [(-50.0, -37.5), (-37.5, -25.0), (-25.0, -12.5), (-12.5, 0.0), (0.0, 12.5), (12.5, 25.0), (25.0, 37.5), (37.5, 50.0), (37.5, 50)]

# %%
max_val = features[model_metrics].max()
min_val = features[model_metrics].min()

# %%
for metric in model_metrics:
    buckets = get_buckets(min_val.loc[metric].round(0), max_val.loc[metric].round(0))
    print(metric, buckets)
# Out:
# oper_margin [(-58.0, -42.75), (-42.75, -27.5), (-27.5, -12.25), (-12.25, 3.0), (3.0, 18.25), (18.25, 33.5), (33.5, 48.75), (48.75, 64.0), (48.75, 64.0)]
# tot_debt_to_tot_eqy [(4.0, 412.62), (412.62, 821.25), (821.25, 1229.88), (1229.88, 1638.5), (1638.5, 2047.12), (2047.12, 2455.75), (2455.75, 2864.38), (2864.38, 3273.0), (2864.38, 3273.0)]
# tot_debt_to_ebitda [(0.0, 7.62), (7.62, 15.25), (15.25, 22.88), (22.88, 30.5), (30.5, 38.12), (38.12, 45.75), (45.75, 53.38), (53.38, 61.0), (53.38, 61.0)]
# ebitda_to_tot_int_exp [(-1.0, 2.12), (2.12, 5.25), (5.25, 8.38), (8.38, 11.5), (11.5, 14.62), (14.62, 17.75), (17.75, 20.88), (20.88, 24.0), (20.88, 24.0)]
# return_on_asset [(-24.0, -18.38), (-18.38, -12.75), (-12.75, -7.12), (-7.12, -1.5), (-1.5, 4.12), (4.12, 9.75), (9.75, 15.38), (15.38, 21.0), (15.38, 21.0)]
# asset_turnover [(0.0, 0.5), (0.5, 1.0), (1.0, 1.5), (1.5, 2.0), (2.0, 2.5), (2.5, 3.0), (3.0, 3.5), (3.5, 4.0), (3.5, 4.0)]
